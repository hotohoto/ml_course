# %% [markdown]
# # Titanic visualization
#
# - https://www.kaggle.com/michaelabehsera/titanic-solution-a-beginner-s-guide
# - https://www.kaggle.com/sashr07/kaggle-titanic-tutorial

# %% [markdown]
# ## Loading

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import missingno as msno

plt.style.use('seaborn')

# %%
df = pd.read_csv("datasets/titanic_train.csv") # we assume we don't have test set.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Passenger_Id                   891 non-null    int64
#  1   Survived                       891 non-null    int64
#  2   Passenger_Class                891 non-null    object
#  3   Name                           891 non-null    object
#  4   Sex                            891 non-null    object
#  5   Age                            714 non-null    float64
#  6   Number_of_Siblings_or_Spouses  891 non-null    int64
#  7   Number_of_Parents_or_Children  891 non-null    int64
#  8   Ticket_Number                  891 non-null    object
#  9   Passenger_Fare                 891 non-null    float64
#  10  Cabin                          204 non-null    object
#  11  Port_of_Embarkation            889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        Passenger_Id    Survived         Age  Number_of_Siblings_or_Spouses  \
# count    891.000000  891.000000  714.000000                     891.000000
# mean     446.000000    0.383838   29.699118                       0.523008
# std      257.353842    0.486592   14.526497                       1.102743
# min        1.000000    0.000000    0.420000                       0.000000
# 25%      223.500000    0.000000   20.125000                       0.000000
# 50%      446.000000    0.000000   28.000000                       0.000000
# 75%      668.500000    1.000000   38.000000                       1.000000
# max      891.000000    1.000000   80.000000                       8.000000
#
#        Number_of_Parents_or_Children  Passenger_Fare
# count                     891.000000      891.000000
# mean                        0.381594       32.204208
# std                         0.806057       49.693429
# min                         0.000000        0.000000
# 25%                         0.000000        7.910400
# 50%                         0.000000       14.454200
# 75%                         0.000000       31.000000
# max                         6.000000      512.329200

# %%
df.describe(include=['object'])
# Out:
#        Passenger_Class                                               Name  \
# count              891                                                891
# unique               3                                                891
# top              Third  Hays, Mrs. Charles Melville (Clara Jennings Gr...
# freq               491                                                  1
#
#          Sex Ticket_Number        Cabin Port_of_Embarkation
# count    891           891          204                 889
# unique     2           681          147                   3
# top     male        347082  C23 C25 C27         Southampton
# freq     577             7            4                 644

# %%
np.random.seed(10)
df.sample(10)
# Out:
#      Passenger_Id  Survived Passenger_Class  \
# 590           591         0           Third
# 131           132         0           Third
# 628           629         0           Third
# 195           196         1           First
# 230           231         1           First
# 646           647         0           Third
# 75             76         0           Third
# 586           587         0          Second
# 569           570         1           Third
# 287           288         0           Third
#
#                                              Name     Sex   Age  \
# 590                          Rintamaki, Mr. Matti    male  35.0
# 131                Coelho, Mr. Domingos Fernandeo    male  20.0
# 628                     Bostandyeff, Mr. Guentcho    male  26.0
# 195                          Lurette, Miss. Elise  female  58.0
# 230  Harris, Mrs. Henry Birkhardt (Irene Wallach)  female  35.0
# 646                             Cor, Mr. Liudevit    male  19.0
# 75                        Moen, Mr. Sigurd Hansen    male  25.0
# 586                       Jarvis, Mr. John Denzil    male  47.0
# 569                             Jonsson, Mr. Carl    male  32.0
# 287                          Naidenoff, Mr. Penko    male  22.0
#
#      Number_of_Siblings_or_Spouses  Number_of_Parents_or_Children  \
# 590                              0                              0
# 131                              0                              0
# 628                              0                              0
# 195                              0                              0
# 230                              1                              0
# 646                              0                              0
# 75                               0                              0
# 586                              0                              0
# 569                              0                              0
# 287                              0                              0
#
#           Ticket_Number  Passenger_Fare  Cabin Port_of_Embarkation
# 590   STON/O 2. 3101273          7.1250    NaN         Southampton
# 131  SOTON/O.Q. 3101307          7.0500    NaN         Southampton
# 628              349224          7.8958    NaN         Southampton
# 195            PC 17569        146.5208    B80           Cherbourg
# 230               36973         83.4750    C83         Southampton
# 646              349231          7.8958    NaN         Southampton
# 75               348123          7.6500  F G73         Southampton
# 586              237565         15.0000    NaN         Southampton
# 569              350417          7.8542    NaN         Southampton
# 287              349206          7.8958    NaN         Southampton

# %%
df.isnull().sum()
# Out:
# Passenger_Id                       0
# Survived                           0
# Passenger_Class                    0
# Name                               0
# Sex                                0
# Age                              177
# Number_of_Siblings_or_Spouses      0
# Number_of_Parents_or_Children      0
# Ticket_Number                      0
# Passenger_Fare                     0
# Cabin                            687
# Port_of_Embarkation                2
# dtype: int64

# %%
msno.matrix(df)
plt.show()

# %%
df.Survived.plot.hist(bins=2)
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
pd.crosstab(df.Survived, df.Passenger_Class, margins=True).style.background_gradient(cmap='Oranges')
# Out:
# <style  type="text/css" >
# #T_3bc4e_row0_col0,#T_3bc4e_row1_col1,#T_3bc4e_row1_col2,#T_3bc4e_row1_col3{
#             background-color:  #fff5eb;
#             color:  #000000;
#         }#T_3bc4e_row0_col1{
#             background-color:  #fee9d3;
#             color:  #000000;
#         }#T_3bc4e_row0_col2{
#             background-color:  #e65a0b;
#             color:  #000000;
#         }#T_3bc4e_row0_col3{
#             background-color:  #fdae6a;
#             color:  #000000;
#         }#T_3bc4e_row1_col0{
#             background-color:  #fda45d;
#             color:  #000000;
#         }#T_3bc4e_row2_col0,#T_3bc4e_row2_col1,#T_3bc4e_row2_col2,#T_3bc4e_row2_col3{
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }</style><table id="T_3bc4e_" ><thead>    <tr>        <th class="index_name level0" >Passenger_Class</th>        <th class="col_heading level0 col0" >First</th>        <th class="col_heading level0 col1" >Second</th>        <th class="col_heading level0 col2" >Third</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3bc4e_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3bc4e_row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_3bc4e_row0_col1" class="data row0 col1" >97</td>
#                         <td id="T_3bc4e_row0_col2" class="data row0 col2" >372</td>
#                         <td id="T_3bc4e_row0_col3" class="data row0 col3" >549</td>
#             </tr>
#             <tr>
#                         <th id="T_3bc4e_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3bc4e_row1_col0" class="data row1 col0" >136</td>
#                         <td id="T_3bc4e_row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_3bc4e_row1_col2" class="data row1 col2" >119</td>
#                         <td id="T_3bc4e_row1_col3" class="data row1 col3" >342</td>
#             </tr>
#             <tr>
#                         <th id="T_3bc4e_level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_3bc4e_row2_col0" class="data row2 col0" >216</td>
#                         <td id="T_3bc4e_row2_col1" class="data row2 col1" >184</td>
#                         <td id="T_3bc4e_row2_col2" class="data row2 col2" >491</td>
#                         <td id="T_3bc4e_row2_col3" class="data row2 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
df[['Survived', 'Passenger_Class']].groupby('Passenger_Class').mean().sort_values(by='Survived', ascending=False).plot.bar()
plt.show()

# %%
pd.crosstab(df.Passenger_Class, df.Survived).plot.bar()
plt.show()

# %%
df.Age.plot(kind='hist')
plt.show()

# %%
# Sex vs. Survival
# df[['Sex', 'Survived']].groupby("Sex").mean().plot(kind="bar")
sns.barplot(x="Sex", y="Survived", data=df)
plt.show()

# %%
sns.violinplot(x="Port_of_Embarkation", y="Age", hue="Survived", data=df, split=True)
plt.show()
sns.violinplot(x="Passenger_Class", y="Age", hue="Survived", data=df, split=True)
plt.show()
sns.violinplot(x="Sex", y="Age", hue="Survived", data=df, split=True)
plt.show()

# %% [markdown]
# ## Correlation measures
#
# Correlation => Dependence
#
# ![relation between correlation and dependence](https://qph.fs.quoracdn.net/main-qimg-5abd437ee5353204779294d3f071e16c)

# %% [markdown]
# ### Prepare numeric fields with naive transformation

# %%
df.head(3)
# Out:
#    Passenger_Id  Survived Passenger_Class  \
# 0             1         0           Third
# 1             2         1           First
# 2             3         1           Third
#
#                                                 Name     Sex   Age  \
# 0                            Braund, Mr. Owen Harris    male  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                             Heikkinen, Miss. Laina  female  26.0
#
#    Number_of_Siblings_or_Spouses  Number_of_Parents_or_Children  \
# 0                              1                              0
# 1                              1                              0
# 2                              0                              0
#
#       Ticket_Number  Passenger_Fare Cabin Port_of_Embarkation
# 0         A/5 21171          7.2500   NaN         Southampton
# 1          PC 17599         71.2833   C85           Cherbourg
# 2  STON/O2. 3101282          7.9250   NaN         Southampton

# %%
df_numeric = df.drop(['Passenger_Id', 'Name', 'Ticket_Number', 'Port_of_Embarkation', 'Cabin'], axis=1)
df_numeric['Sex'] = df_numeric['Sex'].map({"male": 0, "female": 1})
df_numeric['Passenger_Class'] = df_numeric['Passenger_Class'].map({"First": 0, "Second": 1, "Third": 2})
df_numeric = df_numeric.dropna()

# %%
df_numeric.head(3)
# Out:
#    Survived  Passenger_Class  Sex   Age  Number_of_Siblings_or_Spouses  \
# 0         0                2    0  22.0                              1
# 1         1                0    1  38.0                              1
# 2         1                2    1  26.0                              0
#
#    Number_of_Parents_or_Children  Passenger_Fare
# 0                              0          7.2500
# 1                              0         71.2833
# 2                              0          7.9250

# %% [markdown]
# ### Pearson correlation coefficient
#
# - It’s a measure of the strength and the direction of a linear relationship between two variables.
#
# Let's take a look at the formula! 🙂

# %% [markdown]
# ![Pearson correlation coefficient examples](https://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg)

# %% [markdown]
# ![Outlier effect example](https://statistics.laerd.com/spss-tutorials/img/pc/pearson-outliers.png)

# %% [markdown]
# Assumptions:
#
# - Your 2 variables are continuous. ("Your data is interval or ratio." 🤔)
#   - Interval scales: Celious, Farenheit
#   - Ratio scales: Kelvin
#
# - There is a linear relationship between the two variables.
# - There should be no significant outliers.
# - Your variables should be approximately normally distributed.
#   - Check skewness or kurtosis
#   - Alternatively you can draw histogram.
#
# (References)
# - https://en.wikipedia.org/wiki/Pearson_correlation_coefficient
# - https://statistics.laerd.com/spss-tutorials/pearsons-product-moment-correlation-using-spss-statistics.php
# - https://www.scribbr.com/statistics/interval-data/
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html

# %%
corr = df_numeric.corr()
sns.heatmap(corr, vmax=1, vmin=-1, square=True, annot=True, cmap=sns.diverging_palette(20, 220, n=200))
plt.show()
# corr

# %% [markdown]
# ### Spearman's rank correlation coefficient
#
# - Non parameteric test. 🤔
# - Based on the Pearson correlation coefficient but Spearman's rank correlation coefficient has less assumptions
#   - It doesn't rely on the normality.
#   - Ordinal fields can be used.
#
# (References)
# - https://en.wikipedia.org/wiki/Spearman%27s_rank_correlation_coefficient
# - https://ademos.people.uic.edu/Chapter22.html

# %%
corr = df_numeric.corr(method='spearman')
sns.heatmap(corr, vmax=1, vmin=-1, square=True, annot=True, cmap=sns.diverging_palette(20, 220, n=200))
plt.show()

# %% [markdown]
# ### Kendall rank correlation coefficient
#
# - Similar to Spearman's rank correlation
# - Non parameteric test. 🤔
#
# https://en.wikipedia.org/wiki/Kendall_rank_correlation_coefficient

# %%
corr = df_numeric.corr(method='kendall')

sns.heatmap(corr, vmax=1, vmin=-1, square=True, annot=True, cmap=sns.diverging_palette(20, 220, n=200))
plt.show()

# %% [markdown]
# ## Mutual information
#
# - The mutual information (MI) between two quantities is a measure of the extent to which knowledge of one quantity reduces uncertainty about the other.
#
# ![Mutual information examples](https://acp.copernicus.org/articles/18/12699/2018/acp-18-12699-2018-f03-web.png)
#
# - When MI is zero, the quantities are independent.
# - Values above 2.0 or so are uncommon
#
# (References)
#
# - https://en.wikipedia.org/wiki/Mutual_information
# - https://www.kaggle.com/ryanholbrook/mutual-information

# %%
from sklearn.feature_selection import mutual_info_regression

def make_mi_scores(X, y, discrete_features):
    mi_scores = mutual_info_regression(X, y, discrete_features=discrete_features)
    mi_scores = pd.Series(mi_scores, name="MI Scores", index=X.columns)
    mi_scores = mi_scores.sort_values(ascending=False)
    return mi_scores

X = df_numeric.copy()
y = X.pop('Survived')
discrete_features = X.dtypes == int

mi_scores = make_mi_scores(X, y, discrete_features)
mi_scores
# Out:
# Passenger_Fare                   0.150590
# Sex                              0.150182
# Passenger_Class                  0.097863
# Age                              0.030861
# Number_of_Siblings_or_Spouses    0.016453
# Number_of_Parents_or_Children    0.010136
# Name: MI Scores, dtype: float64
