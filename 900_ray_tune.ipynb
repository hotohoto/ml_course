# %% [markdown]
# # Ray.tune test
#
# - https://docs.ray.io/en/master/tune/api_docs/suggestion.html
# - https://docs.ray.io/en/master/tune/api_docs/schedulers.html
#
# ### Requirements
#
# - hyperopt, dill
# - optuna, SQLAlchemy==1.3.24
# - ConfigSpace, hpbandster
# - ray==1.2.0, pickle5

# %%
import time
import numpy as np
import math
import ConfigSpace as CS
import ray
from ray import tune
from ray.tune.schedulers import ASHAScheduler, HyperBandForBOHB
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch
from hyperopt import hp

# %%
# ray.init()
seed = 42

# %%
def visualize(analysis):
    dfs = analysis.trial_dataframes
    for d in dfs.values():
        d.score.plot()
    print(analysis.get_best_config(metric="score", mode="min"))
    print([x.metric_analysis['training_iteration']['last'] for x in analysis.trials])

# %% [markdown]
# ## Define the function to run

# %%
def my_trainable(config):
    def func(x, a, b):
        return np.log((a + b)**2 + ((x-5)**2)/100)

    for x in range(10):
        score = func(x, config["a"], config["b"])
        tune.report(score=score, epoch=(x + 1))

# %% [markdown]
# ## Early stopping with ASHA
#
# - Asynchronous Successive Halving Algorithm
# - A successor of the hyperband algorithm

# %%
search_space = {
    "a": tune.choice([-50, 50]),
    "b": tune.choice([-50, 50]),
}

analysis1 = tune.run(
    my_trainable,
    config=search_space,
    num_samples=10,
    scheduler=ASHAScheduler(metric="score", mode="min", max_t=10),
)
visualize(analysis1)
# Out:
# 2021-04-20 00:51:10,905	INFO services.py:1172 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-04-20 00:51:12,384	WARNING function_runner.py:540 -- Function checkpointing is disabled. This may result in unexpected behavior when using checkpointing features or certain schedulers. To enable, set the train function arguments to be `func(config, checkpoint_dir=None)`.
# == Status ==<br>Memory usage on this node: 3.3/12.4 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 4.000: None | Iter 1.000: None<br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-12<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name              </th><th>status  </th><th>loc  </th><th style="text-align: right;">  a</th><th style="text-align: right;">  b</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_10e12_00000</td><td>RUNNING </td><td>     </td><td style="text-align: right;">-50</td><td style="text-align: right;"> 50</td></tr>
# </tbody>
# </table><br><br>
# Result for my_trainable_10e12_00000:
#   date: 2021-04-20_00-51-13
#   done: false
#   epoch: 1
#   experiment_id: aa8df09b0bd9464aa594d2710e1396bb
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21939
#   score: -1.3862943611198906
#   time_since_restore: 0.01387476921081543
#   time_this_iter_s: 0.01387476921081543
#   time_total_s: 0.01387476921081543
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00000
#
# Result for my_trainable_10e12_00001:
#   date: 2021-04-20_00-51-13
#   done: true
#   epoch: 1
#   experiment_id: 1044b54ae8214ee99b5ee2b1bf444d98
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21940
#   score: 9.210365371663688
#   time_since_restore: 0.0014727115631103516
#   time_this_iter_s: 0.0014727115631103516
#   time_total_s: 0.0014727115631103516
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00001
#
# Result for my_trainable_10e12_00002:
#   date: 2021-04-20_00-51-13
#   done: true
#   epoch: 1
#   experiment_id: 62aa6c1752714d25b2ac21e0031adc12
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21941
#   score: 9.210365371663688
#   time_since_restore: 0.00048732757568359375
#   time_this_iter_s: 0.00048732757568359375
#   time_total_s: 0.00048732757568359375
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00002
#
# Result for my_trainable_10e12_00003:
#   date: 2021-04-20_00-51-13
#   done: false
#   epoch: 1
#   experiment_id: ad8c881944a64b338921a02e524f880f
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21937
#   score: -1.3862943611198906
#   time_since_restore: 0.002537965774536133
#   time_this_iter_s: 0.002537965774536133
#   time_total_s: 0.002537965774536133
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00003
#
# Result for my_trainable_10e12_00004:
#   date: 2021-04-20_00-51-13
#   done: false
#   epoch: 1
#   experiment_id: 5da36088b9e44d35af8c7a1865bcf124
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21936
#   score: -1.3862943611198906
#   time_since_restore: 0.0002789497375488281
#   time_this_iter_s: 0.0002789497375488281
#   time_total_s: 0.0002789497375488281
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00004
#
# Result for my_trainable_10e12_00006:
#   date: 2021-04-20_00-51-13
#   done: false
#   epoch: 1
#   experiment_id: 38050fac2337450dbbb20c05efdb0124
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21935
#   score: -1.3862943611198906
#   time_since_restore: 0.0004413127899169922
#   time_this_iter_s: 0.0004413127899169922
#   time_total_s: 0.0004413127899169922
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00006
# (pid=21939) <ipython-input-4-b8696c0b36bc>:3: RuntimeWarning: divide by zero encountered in log
# WARNING:root:NaN or Inf found in input tensor.
# Result for my_trainable_10e12_00005:
#   date: 2021-04-20_00-51-13
#   done: false
#   epoch: 1
#   experiment_id: a5e0d464c0454b6882c52b8becdbad08
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21938
#   score: -1.3862943611198906
#   time_since_restore: 0.0005078315734863281
#   time_this_iter_s: 0.0005078315734863281
#   time_total_s: 0.0005078315734863281
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00005
#
# Result for my_trainable_10e12_00007:
#   date: 2021-04-20_00-51-13
#   done: false
#   epoch: 1
#   experiment_id: 4c629f147238478097bd9fb8205f40b4
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 21934
#   score: -1.3862943611198906
#   time_since_restore: 0.011646270751953125
#   time_this_iter_s: 0.011646270751953125
#   time_total_s: 0.011646270751953125
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00007
#
# Result for my_trainable_10e12_00000:
#   date: 2021-04-20_00-51-13
#   done: true
#   epoch: 10
#   experiment_id: aa8df09b0bd9464aa594d2710e1396bb
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 21939
#   score: -1.8325814637483102
#   time_since_restore: 0.42287206649780273
#   time_this_iter_s: 0.04598355293273926
#   time_total_s: 0.42287206649780273
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 10e12_00000
# (pid=21935) <ipython-input-4-b8696c0b36bc>:3: RuntimeWarning: divide by zero encountered in log
# (pid=21936) <ipython-input-4-b8696c0b36bc>:3: RuntimeWarning: divide by zero encountered in log
# WARNING:root:NaN or Inf found in input tensor.
# WARNING:root:NaN or Inf found in input tensor.
# (pid=21934) <ipython-input-4-b8696c0b36bc>:3: RuntimeWarning: divide by zero encountered in log
# WARNING:root:NaN or Inf found in input tensor.
# WARNING:root:NaN or Inf found in input tensor.
# (pid=21937) <ipython-input-4-b8696c0b36bc>:3: RuntimeWarning: divide by zero encountered in log
# (pid=21938) <ipython-input-4-b8696c0b36bc>:3: RuntimeWarning: divide by zero encountered in log
# WARNING:root:NaN or Inf found in input tensor.
# Result for my_trainable_10e12_00006:
#   date: 2021-04-20_00-51-13
#   done: true
#   epoch: 10
#   experiment_id: 38050fac2337450dbbb20c05efdb0124
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 21935
#   score: -1.8325814637483102
#   time_since_restore: 0.495377779006958
#   time_this_iter_s: 0.020634174346923828
#   time_total_s: 0.495377779006958
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 10e12_00006
#
# Result for my_trainable_10e12_00007:
#   date: 2021-04-20_00-51-13
#   done: true
#   epoch: 10
#   experiment_id: 4c629f147238478097bd9fb8205f40b4
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 21934
#   score: -1.8325814637483102
#   time_since_restore: 0.5478906631469727
#   time_this_iter_s: 0.008530378341674805
#   time_total_s: 0.5478906631469727
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 10e12_00007
#
# Result for my_trainable_10e12_00003:
#   date: 2021-04-20_00-51-13
#   done: true
#   epoch: 10
#   experiment_id: ad8c881944a64b338921a02e524f880f
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 21937
#   score: -1.8325814637483102
#   time_since_restore: 0.6183149814605713
#   time_this_iter_s: 0.014358043670654297
#   time_total_s: 0.6183149814605713
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 10e12_00003
#
# Result for my_trainable_10e12_00004:
#   date: 2021-04-20_00-51-13
#   done: true
#   epoch: 10
#   experiment_id: 5da36088b9e44d35af8c7a1865bcf124
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 21936
#   score: -1.8325814637483102
#   time_since_restore: 0.4925651550292969
#   time_this_iter_s: 0.01294398307800293
#   time_total_s: 0.4925651550292969
#   timestamp: 1618847473
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 10e12_00004
#
# Result for my_trainable_10e12_00005:
#   date: 2021-04-20_00-51-14
#   done: true
#   epoch: 10
#   experiment_id: a5e0d464c0454b6882c52b8becdbad08
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 21938
#   score: -1.8325814637483102
#   time_since_restore: 0.6747848987579346
#   time_this_iter_s: 0.006274223327636719
#   time_total_s: 0.6747848987579346
#   timestamp: 1618847474
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 10e12_00005
# WARNING:root:NaN or Inf found in input tensor.
# Result for my_trainable_10e12_00008:
#   date: 2021-04-20_00-51-14
#   done: true
#   epoch: 1
#   experiment_id: 4600e2e52d9f44288451f8defe162fb8
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22083
#   score: 9.210365371663688
#   time_since_restore: 0.00032520294189453125
#   time_this_iter_s: 0.00032520294189453125
#   time_total_s: 0.00032520294189453125
#   timestamp: 1618847474
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00008
#
# Result for my_trainable_10e12_00009:
#   date: 2021-04-20_00-51-14
#   done: false
#   epoch: 1
#   experiment_id: 68c99a737f58428d8302b2fbf6c4f3e3
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22084
#   score: -1.3862943611198906
#   time_since_restore: 0.0001728534698486328
#   time_this_iter_s: 0.0001728534698486328
#   time_total_s: 0.0001728534698486328
#   timestamp: 1618847474
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 10e12_00009
#
# Result for my_trainable_10e12_00009:
#   date: 2021-04-20_00-51-14
#   done: true
#   epoch: 10
#   experiment_id: 68c99a737f58428d8302b2fbf6c4f3e3
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22084
#   score: -1.8325814637483102
#   time_since_restore: 0.037406206130981445
#   time_this_iter_s: 0.0032389163970947266
#   time_total_s: 0.037406206130981445
#   timestamp: 1618847474
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 10e12_00009
# (pid=22084) <ipython-input-4-b8696c0b36bc>:3: RuntimeWarning: divide by zero encountered in log
# == Status ==<br>Memory usage on this node: 3.3/12.4 GiB<br>Using AsyncHyperBand: num_stopped=10
# Bracket: Iter 4.000: 3.2188758248682006 | Iter 1.000: 1.3862943611198906<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-12<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name              </th><th>status    </th><th>loc  </th><th style="text-align: right;">  a</th><th style="text-align: right;">  b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   score</th><th style="text-align: right;">  epoch</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_10e12_00000</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-50</td><td style="text-align: right;"> 50</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.422872   </td><td style="text-align: right;">-1.83258</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_10e12_00001</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-50</td><td style="text-align: right;">-50</td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.00147271 </td><td style="text-align: right;"> 9.21037</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_10e12_00002</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 50</td><td style="text-align: right;"> 50</td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.000487328</td><td style="text-align: right;"> 9.21037</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_10e12_00003</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 50</td><td style="text-align: right;">-50</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.618315   </td><td style="text-align: right;">-1.83258</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_10e12_00004</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-50</td><td style="text-align: right;"> 50</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.492565   </td><td style="text-align: right;">-1.83258</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_10e12_00005</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 50</td><td style="text-align: right;">-50</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.674785   </td><td style="text-align: right;">-1.83258</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_10e12_00006</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 50</td><td style="text-align: right;">-50</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.495378   </td><td style="text-align: right;">-1.83258</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_10e12_00007</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 50</td><td style="text-align: right;">-50</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.547891   </td><td style="text-align: right;">-1.83258</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_10e12_00008</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-50</td><td style="text-align: right;">-50</td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.000325203</td><td style="text-align: right;"> 9.21037</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_10e12_00009</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 50</td><td style="text-align: right;">-50</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.0374062  </td><td style="text-align: right;">-1.83258</td><td style="text-align: right;">     10</td></tr>
# </tbody>
# </table><br><br>
# 2021-04-20 00:51:14,363	INFO tune.py:450 -- Total run time: 3.91 seconds (1.57 seconds for the tuning loop).
# {'a': -50, 'b': 50}
# [10, 1, 1, 10, 10, 10, 10, 10, 1, 10]

# %% [markdown]
# ## TPE with Hyperopt

# %%
space = {
    "a": hp.uniform("a", -50, 50),
    "b": hp.uniform("b", -50, 50),
}

analysis2 = tune.run(
    my_trainable,
    num_samples=10,
    search_alg=HyperOptSearch(space, metric="score", mode="min", random_state_seed=seed),
)
visualize(analysis2)
# Out:
# == Status ==<br>Memory usage on this node: 3.2/12.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-14<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th><th style="text-align: right;">      a</th><th style="text-align: right;">       b</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_1237f4de</td><td>RUNNING </td><td>     </td><td style="text-align: right;">33.2632</td><td style="text-align: right;">-4.52989</td></tr>
# </tbody>
# </table><br><br>
# Result for my_trainable_123abc32:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: 9245db111f114501a812280d708859e1
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22087
#   score: 5.248182703942885
#   time_since_restore: 0.00022983551025390625
#   time_this_iter_s: 0.00022983551025390625
#   time_total_s: 0.00022983551025390625
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 123abc32
#
# Result for my_trainable_1237f4de:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: 76339c3be3c34154ae0a3f237181ea34
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22130
#   score: 6.716416809371078
#   time_since_restore: 0.009674310684204102
#   time_this_iter_s: 0.009674310684204102
#   time_total_s: 0.009674310684204102
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1237f4de
#
# Result for my_trainable_123cafc4:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: 58836eef4d954db2b10d49c3b4d36c72
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22093
#   score: 8.555333949559662
#   time_since_restore: 0.002298593521118164
#   time_this_iter_s: 0.002298593521118164
#   time_total_s: 0.002298593521118164
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 123cafc4
#
# Result for my_trainable_123f526a:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: fa39c39ec5ac40199629a622d735b627
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22097
#   score: 7.186880314639872
#   time_since_restore: 0.0005407333374023438
#   time_this_iter_s: 0.0005407333374023438
#   time_total_s: 0.0005407333374023438
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 123f526a
#
# Result for my_trainable_124325ca:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: fc059daec94547988ac8935f2903944f
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22088
#   score: 6.336303562100795
#   time_since_restore: 0.00022935867309570312
#   time_this_iter_s: 0.00022935867309570312
#   time_total_s: 0.00022935867309570312
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 124325ca
#
# Result for my_trainable_1241130c:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: 8d2ba706520e40308118be8ecde481e1
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22092
#   score: 1.0025050907284896
#   time_since_restore: 0.000194549560546875
#   time_this_iter_s: 0.000194549560546875
#   time_total_s: 0.000194549560546875
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1241130c
#
# Result for my_trainable_12457794:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: 1d3411ca23c4488ea09148527e398786
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22081
#   score: 8.419557291128548
#   time_since_restore: 0.00023627281188964844
#   time_this_iter_s: 0.00023627281188964844
#   time_total_s: 0.00023627281188964844
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '12457794'
#
# Result for my_trainable_1237f4de:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: 76339c3be3c34154ae0a3f237181ea34
#   experiment_tag: 1_a=33.263,b=-4.5299
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22130
#   score: 6.7163078252022546
#   time_since_restore: 0.1969165802001953
#   time_this_iter_s: 0.007133007049560547
#   time_total_s: 0.1969165802001953
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 1237f4de
#
# Result for my_trainable_123abc32:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: 9245db111f114501a812280d708859e1
#   experiment_tag: 2_a=22.773,b=-8.9896
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22087
#   score: 5.247709456276105
#   time_since_restore: 0.26613759994506836
#   time_this_iter_s: 0.06505870819091797
#   time_total_s: 0.26613759994506836
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 123abc32
#
# Result for my_trainable_123f526a:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: fa39c39ec5ac40199629a622d735b627
#   experiment_tag: 4_a=41.872,b=-5.5167
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22097
#   score: 7.186812232243999
#   time_since_restore: 0.18855595588684082
#   time_this_iter_s: 0.020496845245361328
#   time_total_s: 0.18855595588684082
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 123f526a
#
# Result for my_trainable_12457794:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: 1d3411ca23c4488ea09148527e398786
#   experiment_tag: 7_a=43.937,b=23.403
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22081
#   score: 8.419537444828755
#   time_since_restore: 0.25284266471862793
#   time_this_iter_s: 0.03792762756347656
#   time_total_s: 0.25284266471862793
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: '12457794'
#
# Result for my_trainable_1247e718:
#   date: 2021-04-20_00-51-15
#   done: false
#   epoch: 1
#   experiment_id: 7661cb9a35034894a582ecb1b72e8f3e
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22250
#   score: 7.3397784908926464
#   time_since_restore: 0.003191709518432617
#   time_this_iter_s: 0.003191709518432617
#   time_total_s: 0.003191709518432617
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1247e718
#
# Result for my_trainable_1241130c:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: 8d2ba706520e40308118be8ecde481e1
#   experiment_tag: 5_a=-32.813,b=31.24
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22092
#   score: 0.9689210968163398
#   time_since_restore: 0.3239731788635254
#   time_this_iter_s: 0.017122983932495117
#   time_total_s: 0.3239731788635254
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 1241130c
#
# Result for my_trainable_123cafc4:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: 58836eef4d954db2b10d49c3b4d36c72
#   experiment_tag: 3_a=38.332,b=33.739
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22093
#   score: 8.555316623015624
#   time_since_restore: 0.44243860244750977
#   time_this_iter_s: 0.15764236450195312
#   time_total_s: 0.44243860244750977
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 123cafc4
#
# Result for my_trainable_124325ca:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: fc059daec94547988ac8935f2903944f
#   experiment_tag: 6_a=-6.1971,b=29.955
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22088
#   score: 6.336144174164725
#   time_since_restore: 0.5184891223907471
#   time_this_iter_s: 0.03197479248046875
#   time_total_s: 0.5184891223907471
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 124325ca
#
# Result for my_trainable_1247e718:
#   date: 2021-04-20_00-51-15
#   done: true
#   epoch: 10
#   experiment_id: 7661cb9a35034894a582ecb1b72e8f3e
#   experiment_tag: 8_a=27.536,b=11.708
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22250
#   score: 7.3397200616980225
#   time_since_restore: 0.28485918045043945
#   time_this_iter_s: 0.0055103302001953125
#   time_total_s: 0.28485918045043945
#   timestamp: 1618847475
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 1247e718
#
# Result for my_trainable_124bfd44:
#   date: 2021-04-20_00-51-16
#   done: false
#   epoch: 1
#   experiment_id: 5fdfcc6dbc7248208bd871ae2f09a229
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22280
#   score: 7.672180504989294
#   time_since_restore: 0.0002465248107910156
#   time_this_iter_s: 0.0002465248107910156
#   time_total_s: 0.0002465248107910156
#   timestamp: 1618847476
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 124bfd44
#
# Result for my_trainable_124bfd44:
#   date: 2021-04-20_00-51-16
#   done: true
#   epoch: 10
#   experiment_id: 5fdfcc6dbc7248208bd871ae2f09a229
#   experiment_tag: 9_a=42.001,b=4.3403
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22280
#   score: 7.672138599979018
#   time_since_restore: 0.03125262260437012
#   time_this_iter_s: 0.0040950775146484375
#   time_total_s: 0.03125262260437012
#   timestamp: 1618847476
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 124bfd44
#
# Result for my_trainable_12a9fb92:
#   date: 2021-04-20_00-51-16
#   done: false
#   epoch: 1
#   experiment_id: 10188dd45ef4465caf3b703d506a9b4e
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22286
#   score: 8.367512586858872
#   time_since_restore: 0.0002512931823730469
#   time_this_iter_s: 0.0002512931823730469
#   time_total_s: 0.0002512931823730469
#   timestamp: 1618847476
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 12a9fb92
#
# Result for my_trainable_12a9fb92:
#   date: 2021-04-20_00-51-16
#   done: true
#   epoch: 10
#   experiment_id: 10188dd45ef4465caf3b703d506a9b4e
#   experiment_tag: 10_a=20.062,b=45.548
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22286
#   score: 8.367491680302418
#   time_since_restore: 0.03642916679382324
#   time_this_iter_s: 0.0037140846252441406
#   time_total_s: 0.03642916679382324
#   timestamp: 1618847476
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 12a9fb92
# == Status ==<br>Memory usage on this node: 3.3/12.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-14<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc  </th><th style="text-align: right;">        a</th><th style="text-align: right;">       b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   score</th><th style="text-align: right;">  epoch</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_1237f4de</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 33.2632 </td><td style="text-align: right;">-4.52989</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.196917 </td><td style="text-align: right;">6.71631 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_123abc32</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 22.7726 </td><td style="text-align: right;">-8.9896 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.266138 </td><td style="text-align: right;">5.24771 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_123cafc4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 38.3315 </td><td style="text-align: right;">33.7388 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.442439 </td><td style="text-align: right;">8.55532 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_123f526a</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 41.8723 </td><td style="text-align: right;">-5.51675</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.188556 </td><td style="text-align: right;">7.18681 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_1241130c</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-32.8128 </td><td style="text-align: right;">31.2396 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.323973 </td><td style="text-align: right;">0.968921</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_124325ca</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> -6.19708</td><td style="text-align: right;">29.9553 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.518489 </td><td style="text-align: right;">6.33614 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_12457794</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 43.937  </td><td style="text-align: right;">23.4028 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.252843 </td><td style="text-align: right;">8.41954 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_1247e718</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 27.5364 </td><td style="text-align: right;">11.7079 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.284859 </td><td style="text-align: right;">7.33972 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_124bfd44</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 42.0009 </td><td style="text-align: right;"> 4.34031</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0312526</td><td style="text-align: right;">7.67214 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_12a9fb92</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 20.0621 </td><td style="text-align: right;">45.5478 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0364292</td><td style="text-align: right;">8.36749 </td><td style="text-align: right;">     10</td></tr>
# </tbody>
# </table><br><br>
# 2021-04-20 00:51:16,580	INFO tune.py:450 -- Total run time: 1.95 seconds (1.91 seconds for the tuning loop).
# {'a': -32.81284386034393, 'b': 31.239598835736317}
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

# %% [markdown]
# ## TPE with Optuna

# %%
config = {
    "a": tune.uniform(-50, 50),
    "b": tune.uniform(-50, 50),
}

optuna_search = OptunaSearch(
    metric="score",
    mode="min",
)

analysis3 = tune.run(
    my_trainable,
    num_samples=10,
    config=config,
    search_alg=optuna_search
)
visualize(analysis3)
# Out:
# [I 2021-04-20 00:51:16,855] A new study created in memory with name: optuna
# == Status ==<br>Memory usage on this node: 3.2/12.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-16<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th><th style="text-align: right;">       a</th><th style="text-align: right;">      b</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_138a8a72</td><td>RUNNING </td><td>     </td><td style="text-align: right;">-45.8673</td><td style="text-align: right;">30.5385</td></tr>
# </tbody>
# </table><br><br>
# Result for my_trainable_138a8a72:
#   date: 2021-04-20_00-51-17
#   done: false
#   epoch: 1
#   experiment_id: 69ee2a74c8c64897aa20a22e3294acb5
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22320
#   score: 5.46052878270348
#   time_since_restore: 0.00019311904907226562
#   time_this_iter_s: 0.00019311904907226562
#   time_total_s: 0.00019311904907226562
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 138a8a72
#
# Result for my_trainable_13915c44:
#   date: 2021-04-20_00-51-17
#   done: false
#   epoch: 1
#   experiment_id: a44ce284960c426690513a35e69abcd7
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22290
#   score: 8.375842100456682
#   time_since_restore: 0.0003211498260498047
#   time_this_iter_s: 0.0003211498260498047
#   time_total_s: 0.0003211498260498047
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 13915c44
#
# Result for my_trainable_138f912a:
#   date: 2021-04-20_00-51-17
#   done: false
#   epoch: 1
#   experiment_id: f02731c7812940849465da57bea35794
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22289
#   score: 4.543401505304522
#   time_since_restore: 0.0009505748748779297
#   time_this_iter_s: 0.0009505748748779297
#   time_total_s: 0.0009505748748779297
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 138f912a
#
# Result for my_trainable_138dcab6:
#   date: 2021-04-20_00-51-17
#   done: false
#   epoch: 1
#   experiment_id: a721a6329ee543dc9d101e6e211939fb
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22288
#   score: 5.87984343127812
#   time_since_restore: 0.010808467864990234
#   time_this_iter_s: 0.010808467864990234
#   time_total_s: 0.010808467864990234
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 138dcab6
#
# Result for my_trainable_1394fd5e:
#   date: 2021-04-20_00-51-17
#   done: false
#   epoch: 1
#   experiment_id: 034d9c6b3eea4656a37fd093b455700e
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22292
#   score: 5.572324597333742
#   time_since_restore: 0.00033783912658691406
#   time_this_iter_s: 0.00033783912658691406
#   time_total_s: 0.00033783912658691406
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1394fd5e
#
# Result for my_trainable_13978e3e:
#   date: 2021-04-20_00-51-17
#   done: false
#   epoch: 1
#   experiment_id: ba17975e384f4326816583540f6a4cab
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22283
#   score: 8.169172379972682
#   time_since_restore: 0.018361806869506836
#   time_this_iter_s: 0.018361806869506836
#   time_total_s: 0.018361806869506836
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 13978e3e
#
# Result for my_trainable_138a8a72:
#   date: 2021-04-20_00-51-17
#   done: true
#   epoch: 10
#   experiment_id: 69ee2a74c8c64897aa20a22e3294acb5
#   experiment_tag: 1_a=-45.867,b=30.539
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22320
#   score: 5.460146091844733
#   time_since_restore: 0.21752548217773438
#   time_this_iter_s: 0.007311344146728516
#   time_total_s: 0.21752548217773438
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 138a8a72
#
# Result for my_trainable_1392eb36:
#   date: 2021-04-20_00-51-17
#   done: false
#   epoch: 1
#   experiment_id: 315ae54792ec4cf784ec5d5e29a0d151
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22284
#   score: 6.610672919337503
#   time_since_restore: 0.00022125244140625
#   time_this_iter_s: 0.00022125244140625
#   time_total_s: 0.00022125244140625
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1392eb36
#
# Result for my_trainable_138dcab6:
#   date: 2021-04-20_00-51-17
#   done: true
#   epoch: 10
#   experiment_id: a721a6329ee543dc9d101e6e211939fb
#   experiment_tag: 2_a=-38.54,b=19.633
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22288
#   score: 5.879591829569391
#   time_since_restore: 0.238433837890625
#   time_this_iter_s: 0.006877422332763672
#   time_total_s: 0.238433837890625
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 138dcab6
#
# Result for my_trainable_13978e3e:
#   date: 2021-04-20_00-51-17
#   done: true
#   epoch: 10
#   experiment_id: ba17975e384f4326816583540f6a4cab
#   experiment_tag: 7_a=45.421,b=13.994
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22283
#   score: 8.169146886936707
#   time_since_restore: 0.39832401275634766
#   time_this_iter_s: 0.12322330474853516
#   time_total_s: 0.39832401275634766
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 13978e3e
#
# Result for my_trainable_1394fd5e:
#   date: 2021-04-20_00-51-17
#   done: true
#   epoch: 10
#   experiment_id: 034d9c6b3eea4656a37fd093b455700e
#   experiment_tag: 6_a=3.8729,b=-20.084
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22292
#   score: 5.571982391828249
#   time_since_restore: 0.46618151664733887
#   time_this_iter_s: 0.08614182472229004
#   time_total_s: 0.46618151664733887
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 1394fd5e
#
# Result for my_trainable_138f912a:
#   date: 2021-04-20_00-51-17
#   done: true
#   epoch: 10
#   experiment_id: f02731c7812940849465da57bea35794
#   experiment_tag: 3_a=28.106,b=-37.789
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22289
#   score: 4.542443702125134
#   time_since_restore: 0.4982774257659912
#   time_this_iter_s: 0.029443740844726562
#   time_total_s: 0.4982774257659912
#   timestamp: 1618847477
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 138f912a
#
# Result for my_trainable_1392eb36:
#   date: 2021-04-20_00-51-18
#   done: true
#   epoch: 10
#   experiment_id: 315ae54792ec4cf784ec5d5e29a0d151
#   experiment_tag: 5_a=-19.886,b=-7.3668
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22284
#   score: 6.610551778647227
#   time_since_restore: 0.5612220764160156
#   time_this_iter_s: 0.010451078414916992
#   time_total_s: 0.5612220764160156
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 1392eb36
#
# Result for my_trainable_13915c44:
#   date: 2021-04-20_00-51-18
#   done: true
#   epoch: 10
#   experiment_id: a44ce284960c426690513a35e69abcd7
#   experiment_tag: 4_a=36.99,b=28.893
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22290
#   score: 8.375821367320224
#   time_since_restore: 0.5852773189544678
#   time_this_iter_s: 0.009583711624145508
#   time_total_s: 0.5852773189544678
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 13915c44
#
# Result for my_trainable_139b056e:
#   date: 2021-04-20_00-51-18
#   done: false
#   epoch: 1
#   experiment_id: 75e34344dfaa401ba5558a6b300b2a6f
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22440
#   score: 6.889427235969775
#   time_since_restore: 0.0002853870391845703
#   time_this_iter_s: 0.0002853870391845703
#   time_total_s: 0.0002853870391845703
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 139b056e
#
# Result for my_trainable_139b056e:
#   date: 2021-04-20_00-51-18
#   done: true
#   epoch: 10
#   experiment_id: 75e34344dfaa401ba5558a6b300b2a6f
#   experiment_tag: 8_a=-10.071,b=41.402
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22440
#   score: 6.889335567035388
#   time_since_restore: 0.08679652214050293
#   time_this_iter_s: 0.008258342742919922
#   time_total_s: 0.08679652214050293
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 139b056e
#
# Result for my_trainable_139f5146:
#   date: 2021-04-20_00-51-18
#   done: false
#   epoch: 1
#   experiment_id: b6f64c25ee2d429390d9bdf97faecf12
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22443
#   score: 8.55476130918762
#   time_since_restore: 0.0002307891845703125
#   time_this_iter_s: 0.0002307891845703125
#   time_total_s: 0.0002307891845703125
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 139f5146
#
# Result for my_trainable_140cac82:
#   date: 2021-04-20_00-51-18
#   done: false
#   epoch: 1
#   experiment_id: b9c19c4df4b14b948d8ac3b57213a050
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22446
#   score: 6.7026063111494505
#   time_since_restore: 0.00033855438232421875
#   time_this_iter_s: 0.00033855438232421875
#   time_total_s: 0.00033855438232421875
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 140cac82
#
# Result for my_trainable_139f5146:
#   date: 2021-04-20_00-51-18
#   done: true
#   epoch: 10
#   experiment_id: b6f64c25ee2d429390d9bdf97faecf12
#   experiment_tag: 9_a=-47.399,b=-24.651
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22443
#   score: 8.554743972718777
#   time_since_restore: 0.08365011215209961
#   time_this_iter_s: 0.007081270217895508
#   time_total_s: 0.08365011215209961
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 139f5146
#
# Result for my_trainable_140cac82:
#   date: 2021-04-20_00-51-18
#   done: true
#   epoch: 10
#   experiment_id: b9c19c4df4b14b948d8ac3b57213a050
#   experiment_tag: 10_a=11.684,b=-40.22
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22446
#   score: 6.702495811329941
#   time_since_restore: 0.0879054069519043
#   time_this_iter_s: 0.008789539337158203
#   time_total_s: 0.0879054069519043
#   timestamp: 1618847478
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 140cac82
# == Status ==<br>Memory usage on this node: 3.3/12.4 GiB<br>Using FIFO scheduling algorithm.<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-16<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc  </th><th style="text-align: right;">        a</th><th style="text-align: right;">        b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  score</th><th style="text-align: right;">  epoch</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_138a8a72</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-45.8673 </td><td style="text-align: right;"> 30.5385 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.217525 </td><td style="text-align: right;">5.46015</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_138dcab6</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-38.5403 </td><td style="text-align: right;"> 19.6326 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.238434 </td><td style="text-align: right;">5.87959</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_138f912a</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 28.1064 </td><td style="text-align: right;">-37.7894 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.498277 </td><td style="text-align: right;">4.54244</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_13915c44</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 36.9904 </td><td style="text-align: right;"> 28.8933 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.585277 </td><td style="text-align: right;">8.37582</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_1392eb36</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-19.8864 </td><td style="text-align: right;"> -7.36676</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.561222 </td><td style="text-align: right;">6.61055</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_1394fd5e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">  3.87292</td><td style="text-align: right;">-20.0839 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.466182 </td><td style="text-align: right;">5.57198</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_13978e3e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 45.421  </td><td style="text-align: right;"> 13.9943 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.398324 </td><td style="text-align: right;">8.16915</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_139b056e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-10.0712 </td><td style="text-align: right;"> 41.4016 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0867965</td><td style="text-align: right;">6.88934</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_139f5146</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-47.3987 </td><td style="text-align: right;">-24.6511 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0836501</td><td style="text-align: right;">8.55474</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_140cac82</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 11.6844 </td><td style="text-align: right;">-40.22   </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0879054</td><td style="text-align: right;">6.7025 </td><td style="text-align: right;">     10</td></tr>
# </tbody>
# </table><br><br>
# 2021-04-20 00:51:18,552	INFO tune.py:450 -- Total run time: 1.70 seconds (1.66 seconds for the tuning loop).
# {'a': 28.106411659917754, 'b': -37.78938808767924}
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10]

# %% [markdown]
# ## TPE with Optuna + ASHA

# %%
config = {
    "a": tune.uniform(-50, 50),
    "b": tune.uniform(-50, 50),
}

optuna_search = OptunaSearch(
    metric="score",
    mode="min",   
)

analysis4 = tune.run(
    my_trainable,
    num_samples=10,
    config=config,
    search_alg=optuna_search,
    scheduler=ASHAScheduler(metric="score", mode="min"),
)
visualize(analysis4)
# Out:
# [I 2021-04-20 00:51:18,899] A new study created in memory with name: optuna
# == Status ==<br>Memory usage on this node: 3.2/12.4 GiB<br>Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: None<br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-18<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th><th style="text-align: right;">       a</th><th style="text-align: right;">      b</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_14c25ea6</td><td>RUNNING </td><td>     </td><td style="text-align: right;">-18.4336</td><td style="text-align: right;">1.83013</td></tr>
# </tbody>
# </table><br><br>
# Result for my_trainable_14c25ea6:
#   date: 2021-04-20_00-51-19
#   done: false
#   epoch: 1
#   experiment_id: d034312e6599443b8b1dfc7bded3f668
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22481
#   score: 5.620131792460598
#   time_since_restore: 0.009899616241455078
#   time_this_iter_s: 0.009899616241455078
#   time_total_s: 0.009899616241455078
#   timestamp: 1618847479
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14c25ea6
#
# Result for my_trainable_14c6d99a:
#   date: 2021-04-20_00-51-19
#   done: true
#   epoch: 1
#   experiment_id: 6deb15b1594f42a58041b6ee7e4eb49a
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22462
#   score: 6.436810879829127
#   time_since_restore: 0.004114389419555664
#   time_this_iter_s: 0.004114389419555664
#   time_total_s: 0.004114389419555664
#   timestamp: 1618847479
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14c6d99a
#
# Result for my_trainable_14ccd458:
#   date: 2021-04-20_00-51-19
#   done: false
#   epoch: 1
#   experiment_id: 65448db144af4bb2ba9d4f85283fe15b
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22459
#   score: 2.273706870780609
#   time_since_restore: 0.018842220306396484
#   time_this_iter_s: 0.018842220306396484
#   time_total_s: 0.018842220306396484
#   timestamp: 1618847479
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14ccd458
#
# Result for my_trainable_14c8d60a:
#   date: 2021-04-20_00-51-19
#   done: true
#   epoch: 1
#   experiment_id: b11a0436b6bf4078b8aadbeb1ea9f6ac
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22448
#   score: 4.780473155660335
#   time_since_restore: 0.017206907272338867
#   time_this_iter_s: 0.017206907272338867
#   time_total_s: 0.017206907272338867
#   timestamp: 1618847479
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14c8d60a
#
# Result for my_trainable_14cadd88:
#   date: 2021-04-20_00-51-19
#   done: false
#   epoch: 1
#   experiment_id: c5c72bbe3b884b33ac7d7795daa56d29
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22450
#   score: 2.9210516555338795
#   time_since_restore: 0.006841897964477539
#   time_this_iter_s: 0.006841897964477539
#   time_total_s: 0.006841897964477539
#   timestamp: 1618847479
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14cadd88
#
# Result for my_trainable_14c25ea6:
#   date: 2021-04-20_00-51-20
#   done: true
#   epoch: 10
#   experiment_id: d034312e6599443b8b1dfc7bded3f668
#   experiment_tag: 1_a=-18.434,b=1.8301
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22481
#   score: 5.619805564544451
#   time_since_restore: 0.5337374210357666
#   time_this_iter_s: 0.03127169609069824
#   time_total_s: 0.5337374210357666
#   timestamp: 1618847480
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 14c25ea6
#
# Result for my_trainable_14ccd458:
#   date: 2021-04-20_00-51-20
#   done: true
#   epoch: 10
#   experiment_id: 65448db144af4bb2ba9d4f85283fe15b
#   experiment_tag: 5_a=23.861,b=-26.938
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22459
#   score: 2.2644000027595927
#   time_since_restore: 0.400118350982666
#   time_this_iter_s: 0.022231101989746094
#   time_total_s: 0.400118350982666
#   timestamp: 1618847480
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 14ccd458
#
# Result for my_trainable_14cadd88:
#   date: 2021-04-20_00-51-20
#   done: true
#   epoch: 10
#   experiment_id: c5c72bbe3b884b33ac7d7795daa56d29
#   experiment_tag: 4_a=17.984,b=-22.263
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22450
#   score: 2.916190931561445
#   time_since_restore: 0.5612106323242188
#   time_this_iter_s: 0.010637283325195312
#   time_total_s: 0.5612106323242188
#   timestamp: 1618847480
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 14cadd88
#
# Result for my_trainable_14d147b8:
#   date: 2021-04-20_00-51-20
#   done: true
#   epoch: 1
#   experiment_id: adc8f2c0ae984b2fb3f54f83174e5277
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22602
#   score: 8.623509713505936
#   time_since_restore: 0.0015647411346435547
#   time_this_iter_s: 0.0015647411346435547
#   time_total_s: 0.0015647411346435547
#   timestamp: 1618847480
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14d147b8
#
# Result for my_trainable_14cefc88:
#   date: 2021-04-20_00-51-20
#   done: true
#   epoch: 1
#   experiment_id: 7763df49bd4d411d96a6aa6b6a2ee2e7
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22598
#   score: 7.615674277645792
#   time_since_restore: 0.0003120899200439453
#   time_this_iter_s: 0.0003120899200439453
#   time_total_s: 0.0003120899200439453
#   timestamp: 1618847480
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14cefc88
#
# Result for my_trainable_14d51e2e:
#   date: 2021-04-20_00-51-20
#   done: true
#   epoch: 1
#   experiment_id: 508788e8d5f5418bb44e2c196a1a4101
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22600
#   score: 5.9549487172859665
#   time_since_restore: 0.00032901763916015625
#   time_this_iter_s: 0.00032901763916015625
#   time_total_s: 0.00032901763916015625
#   timestamp: 1618847480
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14d51e2e
#
# Result for my_trainable_153fc1f2:
#   date: 2021-04-20_00-51-21
#   done: true
#   epoch: 1
#   experiment_id: 8de0f72c5d334edfabc70aa7baa9724c
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22634
#   score: 8.504303016493406
#   time_since_restore: 0.0005123615264892578
#   time_this_iter_s: 0.0005123615264892578
#   time_total_s: 0.0005123615264892578
#   timestamp: 1618847481
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 153fc1f2
#
# Result for my_trainable_14d8436a:
#   date: 2021-04-20_00-51-21
#   done: true
#   epoch: 1
#   experiment_id: 2a9854f2daad4f488249aeb71865bb65
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22614
#   score: 8.033958265185515
#   time_since_restore: 0.0002701282501220703
#   time_this_iter_s: 0.0002701282501220703
#   time_total_s: 0.0002701282501220703
#   timestamp: 1618847481
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 14d8436a
# == Status ==<br>Memory usage on this node: 3.4/12.4 GiB<br>Using AsyncHyperBand: num_stopped=7
# Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: -2.580763774252466 | Iter 1.000: -4.990387814860401<br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-18<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc  </th><th style="text-align: right;">        a</th><th style="text-align: right;">        b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  score</th><th style="text-align: right;">  epoch</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_14c25ea6</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-18.4336 </td><td style="text-align: right;">  1.83013</td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.533737   </td><td style="text-align: right;">5.61981</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_14c6d99a</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-23.9395 </td><td style="text-align: right;"> 48.9228 </td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.00411439 </td><td style="text-align: right;">6.43681</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_14c8d60a</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 26.5878 </td><td style="text-align: right;">-15.6832 </td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.0172069  </td><td style="text-align: right;">4.78047</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_14cadd88</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 17.9836 </td><td style="text-align: right;">-22.2627 </td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.561211   </td><td style="text-align: right;">2.91619</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_14ccd458</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 23.861  </td><td style="text-align: right;">-26.9376 </td><td style="text-align: right;">    10</td><td style="text-align: right;">     0.400118   </td><td style="text-align: right;">2.2644 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_14cefc88</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 10.3604 </td><td style="text-align: right;"> 34.6897 </td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.00031209 </td><td style="text-align: right;">7.61567</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_14d147b8</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 35.1981 </td><td style="text-align: right;"> 39.3715 </td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.00156474 </td><td style="text-align: right;">8.62351</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_14d51e2e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-25.3755 </td><td style="text-align: right;">  5.74376</td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.000329018</td><td style="text-align: right;">5.95495</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_14d8436a</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">  6.66303</td><td style="text-align: right;"> 48.8678 </td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.000270128</td><td style="text-align: right;">8.03396</td><td style="text-align: right;">      1</td></tr>
# <tr><td>my_trainable_153fc1f2</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 49.0742 </td><td style="text-align: right;"> 21.1804 </td><td style="text-align: right;">     1</td><td style="text-align: right;">     0.000512362</td><td style="text-align: right;">8.5043 </td><td style="text-align: right;">      1</td></tr>
# </tbody>
# </table><br><br>
# 2021-04-20 00:51:21,369	INFO tune.py:450 -- Total run time: 2.48 seconds (2.42 seconds for the tuning loop).
# {'a': 23.86101432564209, 'b': -26.93759484403705}
# [10, 1, 1, 10, 10, 1, 1, 1, 1, 1]

# %% [markdown]
# ## BOHB with TuneBOHB

# %%
config = {
    "a": tune.uniform(-50, 50),
    "b": tune.uniform(-50, 50),
}

algo = ConcurrencyLimiter(
    TuneBOHB(metric="score", mode="min", seed=seed),
    max_concurrent=4,
)
bohb = HyperBandForBOHB(
    time_attr="training_iteration",
    metric="score",
    mode="min",
    max_t=100,
)
analysis5 = tune.run(
    my_trainable,
    num_samples=10, # this needs to be specified, or all the config generated would be the same.
    config=config,
    scheduler=bohb,
    search_alg=algo,
)
visualize(analysis5)
# Out:
# 2021-04-20 00:51:22,119	WARNING suggestion.py:263 -- save not implemented for Searcher. Skipping save.
# == Status ==<br>Memory usage on this node: 3.3/12.4 GiB<br>Using HyperBand: num_stopped=0 total_brackets=1
# Round #0:
#   Bracket(Max Size (n)=81, Milestone (r)=1, completed=0.0%): {RUNNING: 1} <br>Resources requested: 1/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22<br>Number of trials: 1/10 (1 RUNNING)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc  </th><th style="text-align: right;">      a</th><th style="text-align: right;">      b</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_16aaeae4</td><td>RUNNING </td><td>     </td><td style="text-align: right;">-12.546</td><td style="text-align: right;">45.0714</td></tr>
# </tbody>
# </table><br><br>
# Result for my_trainable_16aaeae4:
#   date: 2021-04-20_00-51-22
#   done: false
#   epoch: 1
#   experiment_id: fbd691e1cf914b7ba409d80c44c22c94
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22700
#   score: 6.964281548361162
#   time_since_restore: 0.000335693359375
#   time_this_iter_s: 0.000335693359375
#   time_total_s: 0.000335693359375
#   timestamp: 1618847482
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 16aaeae4
#
# Result for my_trainable_16b21008:
#   date: 2021-04-20_00-51-22
#   done: false
#   epoch: 1
#   experiment_id: 30dca67a85d44a44bc82d03e3763d5da
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22637
#   score: 4.053797576208638
#   time_since_restore: 0.00028133392333984375
#   time_this_iter_s: 0.00028133392333984375
#   time_total_s: 0.00028133392333984375
#   timestamp: 1618847482
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 16b21008
#
# Result for my_trainable_16ae3500:
#   date: 2021-04-20_00-51-22
#   done: false
#   epoch: 1
#   experiment_id: 4bee701d649948bcbb7f8e1a31f4b7c3
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22660
#   score: 6.997193953598211
#   time_since_restore: 0.00027370452880859375
#   time_this_iter_s: 0.00027370452880859375
#   time_total_s: 0.00027370452880859375
#   timestamp: 1618847482
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 16ae3500
#
# Result for my_trainable_16b03be8:
#   date: 2021-04-20_00-51-22
#   done: false
#   epoch: 1
#   experiment_id: 9e03b2f6479d4f12b1b9ceb93958bffe
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22650
#   score: 8.462422047772305
#   time_since_restore: 0.000301361083984375
#   time_this_iter_s: 0.000301361083984375
#   time_total_s: 0.000301361083984375
#   timestamp: 1618847482
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 16b03be8
# 2021-04-20 00:51:23,645	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=1; Now=1
# 2021-04-20 00:51:23,661	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=1; Now=1
# (pid=22640) 2021-04-20 00:51:23,656	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16ae3500_2_a=23.199,b=9.8658_2021-04-20_00-51-22/checkpoint_tmpeeb9fd/./
# (pid=22640) 2021-04-20 00:51:23,657	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.00027370452880859375, '_episodes_total': 0}
# (pid=22647) 2021-04-20 00:51:23,642	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16aaeae4_1_a=-12.546,b=45.071_2021-04-20_00-51-22/checkpoint_tmpb7e0b4/./
# (pid=22647) 2021-04-20 00:51:23,642	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.000335693359375, '_episodes_total': 0}
# (pid=22626) 2021-04-20 00:51:23,677	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16b03be8_3_a=-34.398,b=-34.401_2021-04-20_00-51-22/checkpoint_tmpc7509c/./
# (pid=22626) 2021-04-20 00:51:23,677	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.000301361083984375, '_episodes_total': 0}
# 2021-04-20 00:51:23,818	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=1; Now=1
# 2021-04-20 00:51:24,081	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=1; Now=1
# (pid=22829) 2021-04-20 00:51:24,033	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16b21008_4_a=-44.192,b=36.618_2021-04-20_00-51-22/checkpoint_tmp68f122/./
# (pid=22829) 2021-04-20 00:51:24,033	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.00028133392333984375, '_episodes_total': 0}
# 2021-04-20 00:51:25,222	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# (pid=22859) 2021-04-20 00:51:25,219	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16ae3500_2_a=23.199,b=9.8658_2021-04-20_00-51-22/checkpoint_tmpbad500/./
# (pid=22859) 2021-04-20 00:51:25,219	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.15856671333312988, '_episodes_total': 0}
# 2021-04-20 00:51:25,240	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# (pid=22857) 2021-04-20 00:51:25,229	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16aaeae4_1_a=-12.546,b=45.071_2021-04-20_00-51-22/checkpoint_tmpe578b8/./
# (pid=22857) 2021-04-20 00:51:25,229	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.01828289031982422, '_episodes_total': 0}
# (pid=22861) 2021-04-20 00:51:25,284	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16b03be8_3_a=-34.398,b=-34.401_2021-04-20_00-51-22/checkpoint_tmp9a53bc/./
# (pid=22861) 2021-04-20 00:51:25,284	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.2716665267944336, '_episodes_total': 0}
# (pid=22863) 2021-04-20 00:51:25,285	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16b21008_4_a=-44.192,b=36.618_2021-04-20_00-51-22/checkpoint_tmp0f5af8/./
# (pid=22863) 2021-04-20 00:51:25,285	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.0664680004119873, '_episodes_total': 0}
# 2021-04-20 00:51:25,300	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# 2021-04-20 00:51:25,323	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# 2021-04-20 00:51:26,386	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=9; Now=1
# 2021-04-20 00:51:26,397	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=9; Now=1
# (pid=22895) 2021-04-20 00:51:26,382	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16ae3500_2_a=23.199,b=9.8658_2021-04-20_00-51-22/checkpoint_tmp27ec62/./
# (pid=22895) 2021-04-20 00:51:26,382	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.7516133785247803, '_episodes_total': 0}
# (pid=22911) 2021-04-20 00:51:26,382	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16aaeae4_1_a=-12.546,b=45.071_2021-04-20_00-51-22/checkpoint_tmp168ec1/./
# (pid=22911) 2021-04-20 00:51:26,382	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.3448812961578369, '_episodes_total': 0}
# (pid=22889) 2021-04-20 00:51:26,403	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_16b21008_4_a=-44.192,b=36.618_2021-04-20_00-51-22/checkpoint_tmp9c7401/./
# (pid=22889) 2021-04-20 00:51:26,403	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.3101952075958252, '_episodes_total': 0}
# 2021-04-20 00:51:26,419	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=9; Now=1
# Result for my_trainable_16aaeae4:
#   date: 2021-04-20_00-51-26
#   done: true
#   episodes_total: 0
#   epoch: 10
#   experiment_id: fbd691e1cf914b7ba409d80c44c22c94
#   experiment_tag: 1_a=-12.546,b=45.071
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22911
#   score: 6.964196490994621
#   time_since_restore: 0.18800687789916992
#   time_this_iter_s: 0.01223444938659668
#   time_total_s: 0.5328881740570068
#   timestamp: 1618847486
#   timesteps_since_restore: 0
#   timesteps_total: 0
#   training_iteration: 10
#   trial_id: 16aaeae4
#
# Result for my_trainable_16b21008:
#   date: 2021-04-20_00-51-26
#   done: true
#   episodes_total: 0
#   epoch: 10
#   experiment_id: 30dca67a85d44a44bc82d03e3763d5da
#   experiment_tag: 4_a=-44.192,b=36.618
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22889
#   score: 4.052234284546439
#   time_since_restore: 0.16045522689819336
#   time_this_iter_s: 0.013900518417358398
#   time_total_s: 0.47065043449401855
#   timestamp: 1618847486
#   timesteps_since_restore: 0
#   timesteps_total: 0
#   training_iteration: 10
#   trial_id: 16b21008
#
# Result for my_trainable_16ae3500:
#   date: 2021-04-20_00-51-26
#   done: true
#   episodes_total: 0
#   epoch: 10
#   experiment_id: 4bee701d649948bcbb7f8e1a31f4b7c3
#   experiment_tag: 2_a=23.199,b=9.8658
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 22895
#   score: 6.997111650220596
#   time_since_restore: 0.2358705997467041
#   time_this_iter_s: 0.038228511810302734
#   time_total_s: 0.9874839782714844
#   timestamp: 1618847486
#   timesteps_since_restore: 0
#   timesteps_total: 0
#   training_iteration: 10
#   trial_id: 16ae3500
#
# Result for my_trainable_18f5a60e:
#   date: 2021-04-20_00-51-26
#   done: false
#   epoch: 1
#   experiment_id: 88def81cec2946aebb3a3da0e425d2cc
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 22981
#   score: 6.862987651566333
#   time_since_restore: 0.017186403274536133
#   time_this_iter_s: 0.017186403274536133
#   time_total_s: 0.017186403274536133
#   timestamp: 1618847486
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 18f5a60e
# == Status ==<br>Memory usage on this node: 3.3/12.4 GiB<br>Using HyperBand: num_stopped=1 total_brackets=2
# Round #0:
#   Bracket(Max Size (n)=1, Milestone (r)=73, completed=100.0%): {TERMINATED: 4}
#   Bracket(Max Size (n)=34, Milestone (r)=3, completed=-0.6%): {PAUSED: 1, RUNNING: 3} <br>Resources requested: 3/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22<br>Number of trials: 8/10 (1 PAUSED, 3 RUNNING, 4 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc  </th><th style="text-align: right;">       a</th><th style="text-align: right;">        b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">  score</th><th style="text-align: right;">  epoch</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_1959a42e</td><td>RUNNING   </td><td>     </td><td style="text-align: right;">-47.9416</td><td style="text-align: right;"> 46.991  </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">       </td><td style="text-align: right;">       </td></tr>
# <tr><td>my_trainable_195d6adc</td><td>RUNNING   </td><td>     </td><td style="text-align: right;"> 33.2443</td><td style="text-align: right;">-28.7661 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">       </td><td style="text-align: right;">       </td></tr>
# <tr><td>my_trainable_19630488</td><td>RUNNING   </td><td>     </td><td style="text-align: right;">-31.8175</td><td style="text-align: right;">-31.6595 </td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">       </td><td style="text-align: right;">       </td></tr>
# <tr><td>my_trainable_18f5a60e</td><td>PAUSED    </td><td>     </td><td style="text-align: right;"> 10.1115</td><td style="text-align: right;"> 20.8073 </td><td style="text-align: right;">     3</td><td style="text-align: right;">        0.048219</td><td style="text-align: right;">    </td><td style="text-align: right;">6.86282</td><td style="text-align: right;">      3</td></tr>
# <tr><td>my_trainable_16aaeae4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-12.546 </td><td style="text-align: right;"> 45.0714 </td><td style="text-align: right;">    10</td><td style="text-align: right;">        0.532888</td><td style="text-align: right;">   0</td><td style="text-align: right;">6.9642 </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_16ae3500</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 23.1994</td><td style="text-align: right;">  9.86585</td><td style="text-align: right;">    10</td><td style="text-align: right;">        0.987484</td><td style="text-align: right;">   0</td><td style="text-align: right;">6.99711</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_16b03be8</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-34.3981</td><td style="text-align: right;">-34.4005 </td><td style="text-align: right;">     9</td><td style="text-align: right;">        0.382707</td><td style="text-align: right;">   0</td><td style="text-align: right;">8.46239</td><td style="text-align: right;">      9</td></tr>
# <tr><td>my_trainable_16b21008</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-44.1916</td><td style="text-align: right;"> 36.6176 </td><td style="text-align: right;">    10</td><td style="text-align: right;">        0.47065 </td><td style="text-align: right;">   0</td><td style="text-align: right;">4.05223</td><td style="text-align: right;">     10</td></tr>
# </tbody>
# </table><br><br>
# Result for my_trainable_19630488:
#   date: 2021-04-20_00-51-27
#   done: false
#   epoch: 1
#   experiment_id: b4a51d9d953a4e6d95f77bebb5b06c74
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 23013
#   score: 8.301418961809018
#   time_since_restore: 0.0002884864807128906
#   time_this_iter_s: 0.0002884864807128906
#   time_total_s: 0.0002884864807128906
#   timestamp: 1618847487
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: '19630488'
#
# Result for my_trainable_1959a42e:
#   date: 2021-04-20_00-51-28
#   done: false
#   epoch: 1
#   experiment_id: 8c863df0bd124d9088976727d2b8ee65
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 23005
#   score: 0.1428653762118686
#   time_since_restore: 0.0003840923309326172
#   time_this_iter_s: 0.0003840923309326172
#   time_total_s: 0.0003840923309326172
#   timestamp: 1618847488
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1959a42e
#
# Result for my_trainable_195d6adc:
#   date: 2021-04-20_00-51-28
#   done: false
#   epoch: 1
#   experiment_id: 0d4773ca13f14a7f9600354f3e0106cb
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 23007
#   score: 3.0108205042999634
#   time_since_restore: 0.0004901885986328125
#   time_this_iter_s: 0.0004901885986328125
#   time_total_s: 0.0004901885986328125
#   timestamp: 1618847488
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 195d6adc
# 2021-04-20 00:51:28,971	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# 2021-04-20 00:51:29,027	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# (pid=23036) 2021-04-20 00:51:29,021	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_1959a42e_6_a=-47.942,b=46.991_2021-04-20_00-51-26/checkpoint_tmp01fcb7/./
# (pid=23036) 2021-04-20 00:51:29,021	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.15294551849365234, '_episodes_total': 0}
# (pid=23060) 2021-04-20 00:51:28,964	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_18f5a60e_5_a=10.112,b=20.807_2021-04-20_00-51-25/checkpoint_tmp809979/./
# (pid=23060) 2021-04-20 00:51:28,964	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.04821896553039551, '_episodes_total': 0}
# 2021-04-20 00:51:29,061	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# (pid=23011) 2021-04-20 00:51:29,050	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_19630488_8_a=-31.818,b=-31.66_2021-04-20_00-51-26/checkpoint_tmp84fb31/./
# (pid=23011) 2021-04-20 00:51:29,050	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.02731633186340332, '_episodes_total': 0}
# (pid=23025) 2021-04-20 00:51:29,028	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_195d6adc_7_a=33.244,b=-28.766_2021-04-20_00-51-26/checkpoint_tmpfb517e/./
# (pid=23025) 2021-04-20 00:51:29,028	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.1452312469482422, '_episodes_total': 0}
# 2021-04-20 00:51:29,234	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=3; Now=1
# 2021-04-20 00:51:30,173	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=9; Now=1
# 2021-04-20 00:51:30,184	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=9; Now=1
# 2021-04-20 00:51:30,211	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=9; Now=1
# (pid=23008) 2021-04-20 00:51:30,169	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_195d6adc_7_a=33.244,b=-28.766_2021-04-20_00-51-26/checkpoint_tmp11b71d/./
# (pid=23008) 2021-04-20 00:51:30,170	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.5941059589385986, '_episodes_total': 0}
# (pid=23010) 2021-04-20 00:51:30,197	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_1959a42e_6_a=-47.942,b=46.991_2021-04-20_00-51-26/checkpoint_tmp8815f6/./
# (pid=23010) 2021-04-20 00:51:30,197	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.45899200439453125, '_episodes_total': 0}
# (pid=23012) 2021-04-20 00:51:30,170	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_18f5a60e_5_a=10.112,b=20.807_2021-04-20_00-51-25/checkpoint_tmpb6c695/./
# (pid=23012) 2021-04-20 00:51:30,170	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.1674661636352539, '_episodes_total': 0}
# Result for my_trainable_195d6adc:
#   date: 2021-04-20_00-51-30
#   done: true
#   episodes_total: 0
#   epoch: 10
#   experiment_id: 0d4773ca13f14a7f9600354f3e0106cb
#   experiment_tag: 7_a=33.244,b=-28.766
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 23008
#   score: 3.006378038526816
#   time_since_restore: 0.14437055587768555
#   time_this_iter_s: 0.011916637420654297
#   time_total_s: 0.7384765148162842
#   timestamp: 1618847490
#   timesteps_since_restore: 0
#   timesteps_total: 0
#   training_iteration: 10
#   trial_id: 195d6adc
#
# Result for my_trainable_1959a42e:
#   date: 2021-04-20_00-51-30
#   done: true
#   episodes_total: 0
#   epoch: 10
#   experiment_id: 8c863df0bd124d9088976727d2b8ee65
#   experiment_tag: 6_a=-47.942,b=46.991
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 23010
#   score: 0.061635398004388595
#   time_since_restore: 0.13298368453979492
#   time_this_iter_s: 0.010404109954833984
#   time_total_s: 0.5919756889343262
#   timestamp: 1618847490
#   timesteps_since_restore: 0
#   timesteps_total: 0
#   training_iteration: 10
#   trial_id: 1959a42e
#
# Result for my_trainable_18f5a60e:
#   date: 2021-04-20_00-51-30
#   done: true
#   episodes_total: 0
#   epoch: 10
#   experiment_id: 88def81cec2946aebb3a3da0e425d2cc
#   experiment_tag: 5_a=10.112,b=20.807
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 23012
#   score: 6.862893526502913
#   time_since_restore: 0.2570075988769531
#   time_this_iter_s: 0.00969243049621582
#   time_total_s: 0.42447376251220703
#   timestamp: 1618847490
#   timesteps_since_restore: 0
#   timesteps_total: 0
#   training_iteration: 10
#   trial_id: 18f5a60e
# (pid=23191) 2021-04-20 00:51:30,746	INFO trainable.py:371 -- Restored on 172.17.154.109 from checkpoint: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22/my_trainable_19630488_8_a=-31.818,b=-31.66_2021-04-20_00-51-26/checkpoint_tmp9ebc73/./
# (pid=23191) 2021-04-20 00:51:30,747	INFO trainable.py:379 -- Current state after restoring: {'_iteration': 0, '_timesteps_total': 0, '_time_total': 0.5988776683807373, '_episodes_total': 0}
# 2021-04-20 00:51:30,775	INFO hyperband.py:441 -- Restoring from a previous point in time. Previous=9; Now=1
# Result for my_trainable_19630488:
#   date: 2021-04-20_00-51-30
#   done: true
#   episodes_total: 0
#   epoch: 10
#   experiment_id: b4a51d9d953a4e6d95f77bebb5b06c74
#   experiment_tag: 8_a=-31.818,b=-31.66
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 23191
#   score: 8.301396626759876
#   time_since_restore: 0.13652586936950684
#   time_this_iter_s: 0.009377717971801758
#   time_total_s: 0.7354035377502441
#   timestamp: 1618847490
#   timesteps_since_restore: 0
#   timesteps_total: 0
#   training_iteration: 10
#   trial_id: '19630488'
# 2021-04-20 00:51:31,798	WARNING tune.py:429 -- Trial Runner checkpointing failed: Checkpoint must not be in-memory.
# Result for my_trainable_1b941832:
#   date: 2021-04-20_00-51-31
#   done: false
#   epoch: 1
#   experiment_id: 13829c36cd00436e84f8151154262178
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 23214
#   score: 5.679027014212735
#   time_since_restore: 0.00024509429931640625
#   time_this_iter_s: 0.00024509429931640625
#   time_total_s: 0.00024509429931640625
#   timestamp: 1618847491
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1b941832
#
# Result for my_trainable_1b9913b4:
#   date: 2021-04-20_00-51-31
#   done: false
#   epoch: 1
#   experiment_id: 49ed835d85fc452c81d9c4f20c0dfadf
#   hostname: hotohoto-nb
#   iterations_since_restore: 1
#   node_ip: 172.17.154.109
#   pid: 23218
#   score: 6.641933145309956
#   time_since_restore: 0.00035762786865234375
#   time_this_iter_s: 0.00035762786865234375
#   time_total_s: 0.00035762786865234375
#   timestamp: 1618847491
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 1b9913b4
#
# Result for my_trainable_1b941832:
#   date: 2021-04-20_00-51-31
#   done: true
#   epoch: 10
#   experiment_id: 13829c36cd00436e84f8151154262178
#   experiment_tag: 9_a=-19.576,b=2.4756
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 23214
#   score: 5.678719447592648
#   time_since_restore: 0.08374404907226562
#   time_this_iter_s: 0.013613462448120117
#   time_total_s: 0.08374404907226562
#   timestamp: 1618847491
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 1b941832
#
# Result for my_trainable_1b9913b4:
#   date: 2021-04-20_00-51-31
#   done: true
#   epoch: 10
#   experiment_id: 49ed835d85fc452c81d9c4f20c0dfadf
#   experiment_tag: 10_a=-6.8055,b=-20.877
#   hostname: hotohoto-nb
#   iterations_since_restore: 10
#   node_ip: 172.17.154.109
#   pid: 23218
#   score: 6.641815733146438
#   time_since_restore: 0.09893035888671875
#   time_this_iter_s: 0.0055119991302490234
#   time_total_s: 0.09893035888671875
#   timestamp: 1618847491
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 1b9913b4
# == Status ==<br>Memory usage on this node: 3.4/12.4 GiB<br>Using HyperBand: num_stopped=1 total_brackets=2
# Round #0:
#   Bracket(Max Size (n)=1, Milestone (r)=73, completed=100.0%): {TERMINATED: 4}
#   Bracket(Max Size (n)=2, Milestone (r)=73, completed=100.0%): {TERMINATED: 6} <br>Resources requested: 0/8 CPUs, 0/0 GPUs, 0.0/5.91 GiB heap, 0.0/2.0 GiB objects<br>Result logdir: /home/hotohoto/ray_results/my_trainable_2021-04-20_00-51-22<br>Number of trials: 10/10 (10 TERMINATED)<br><table>
# <thead>
# <tr><th>Trial name           </th><th>status    </th><th>loc  </th><th style="text-align: right;">       a</th><th style="text-align: right;">        b</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">    score</th><th style="text-align: right;">  epoch</th></tr>
# </thead>
# <tbody>
# <tr><td>my_trainable_16aaeae4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-12.546 </td><td style="text-align: right;"> 45.0714 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.532888 </td><td style="text-align: right;">   0</td><td style="text-align: right;">6.9642   </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_16ae3500</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 23.1994</td><td style="text-align: right;">  9.86585</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.987484 </td><td style="text-align: right;">   0</td><td style="text-align: right;">6.99711  </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_16b03be8</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-34.3981</td><td style="text-align: right;">-34.4005 </td><td style="text-align: right;">     9</td><td style="text-align: right;">       0.382707 </td><td style="text-align: right;">   0</td><td style="text-align: right;">8.46239  </td><td style="text-align: right;">      9</td></tr>
# <tr><td>my_trainable_16b21008</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-44.1916</td><td style="text-align: right;"> 36.6176 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.47065  </td><td style="text-align: right;">   0</td><td style="text-align: right;">4.05223  </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_18f5a60e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 10.1115</td><td style="text-align: right;"> 20.8073 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.424474 </td><td style="text-align: right;">   0</td><td style="text-align: right;">6.86289  </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_1959a42e</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-47.9416</td><td style="text-align: right;"> 46.991  </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.591976 </td><td style="text-align: right;">   0</td><td style="text-align: right;">0.0616354</td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_195d6adc</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> 33.2443</td><td style="text-align: right;">-28.7661 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.738477 </td><td style="text-align: right;">   0</td><td style="text-align: right;">3.00638  </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_19630488</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-31.8175</td><td style="text-align: right;">-31.6595 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.735404 </td><td style="text-align: right;">   0</td><td style="text-align: right;">8.3014   </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_1b941832</td><td>TERMINATED</td><td>     </td><td style="text-align: right;">-19.5758</td><td style="text-align: right;">  2.47564</td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.083744 </td><td style="text-align: right;">    </td><td style="text-align: right;">5.67872  </td><td style="text-align: right;">     10</td></tr>
# <tr><td>my_trainable_1b9913b4</td><td>TERMINATED</td><td>     </td><td style="text-align: right;"> -6.8055</td><td style="text-align: right;">-20.8771 </td><td style="text-align: right;">    10</td><td style="text-align: right;">       0.0989304</td><td style="text-align: right;">    </td><td style="text-align: right;">6.64182  </td><td style="text-align: right;">     10</td></tr>
# </tbody>
# </table><br><br>
# 2021-04-20 00:51:31,811	INFO tune.py:450 -- Total run time: 9.72 seconds (9.70 seconds for the tuning loop).
# {'a': -47.94155057041976, 'b': 46.990985216199434}
# [10, 10, 9, 10, 10, 10, 10, 10, 10, 10]
